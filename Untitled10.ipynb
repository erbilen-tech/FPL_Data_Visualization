# %% [markdown]
# <a href="https://colab.research.google.com/github/erbilen-tech/FPL_Data_Visualization/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
print (cv2.__version__)
# Out:
# 3.4.2

# %% [markdown]
# Divided a big panoramic image into two parts with few overlapping regions.
# Below images show the left and right side of cropped image along with the key points that are selected using SIFT algorithm.

# %%
#Right
imageRight = cv2.imread('2.jpg')
imageRight = cv2.resize(imageRight,(700,500),None,0.1,0.1)
imageRightgray = cv2.cvtColor(imageRight,cv2.COLOR_RGB2GRAY)

# %%
#Left
imageLeft = cv2.imread('1.jpg')
imageLeft = cv2.resize(imageLeft,(700,500),None,0.1,0.1)
imageLeftGray = cv2.cvtColor(imageLeft,cv2.COLOR_RGB2GRAY)

# %%
#using Shift from cv2
sift = cv2.xfeatures2d.SIFT_create()
# find Keypoints
kpr, desr = sift.detectAndCompute(imageRight,None)
kpl, desl = sift.detectAndCompute(imageLeft,None)

# %%
pip install opencv-python==3.4.2.16
# Out:
# Requirement already satisfied: opencv-python==3.4.2.16 in /usr/local/lib/python3.6/dist-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.16) (1.18.5)

# %%
pip install opencv-contrib-python==3.4.2.16
# Out:
# Requirement already satisfied: opencv-contrib-python==3.4.2.16 in /usr/local/lib/python3.6/dist-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python==3.4.2.16) (1.18.5)

# %%
match = cv2.BFMatcher()
matches = match.knnMatch(desr,desl,k=2)
print(matches)
# Out:
# [[<DMatch 0x7f03f22d2ad0>, <DMatch 0x7f03f22d2cb0>], [<DMatch 0x7f03f22d2b70>, <DMatch 0x7f03f22d2cf0>], [<DMatch 0x7f03f22d2c50>, <DMatch 0x7f03f22d2cd0>], [<DMatch 0x7f03f22d2d10>, <DMatch 0x7f03f22d2b90>], [<DMatch 0x7f03f22d2a90>, <DMatch 0x7f03f22d2d30>], [<DMatch 0x7f03f22d2d50>, <DMatch 0x7f03f22d2d70>], [<DMatch 0x7f03f22d2d90>, <DMatch 0x7f03f22d2db0>], [<DMatch 0x7f03f22d2dd0>, <DMatch 0x7f03f22d2df0>], [<DMatch 0x7f03f22d2e10>, <DMatch 0x7f03f22d2e30>], [<DMatch 0x7f03f22d2e50>, <DMatch 0x7f03f22d2e70>], [<DMatch 0x7f03f22d2e90>, <DMatch 0x7f03f22d2eb0>], [<DMatch 0x7f03f22d2ed0>, <DMatch 0x7f03f22d2ef0>], [<DMatch 0x7f03f22d2f10>, <DMatch 0x7f03f22d2f30>], [<DMatch 0x7f03f22d2f50>, <DMatch 0x7f03f22d2f70>], [<DMatch 0x7f03f22d2f90>, <DMatch 0x7f03f22d2fb0>], [<DMatch 0x7f03f22d2fd0>, <DMatch 0x7f03f2224030>], [<DMatch 0x7f03f2224050>, <DMatch 0x7f03f2224070>], [<DMatch 0x7f03f2224090>, <DMatch 0x7f03f22240b0>], [<DMatch 0x7f03f22240d0>, <DMatch 0x7f03f22240f0>], [<DMatch 0x7f03f2224110>, <DMatch 0x7f03f2224130>], [<DMatch 0x7f03f2224150>, <DMatch 0x7f03f2224170>], [<DMatch 0x7f03f2224190>, <DMatch 0x7f03f22241b0>], [<DMatch 0x7f03f22241d0>, <DMatch 0x7f03f22241f0>], [<DMatch 0x7f03f2224210>, <DMatch 0x7f03f2224230>], [<DMatch 0x7f03f2224250>, <DMatch 0x7f03f2224270
DMatch 0x7f03f2224d50>, <DMatch 0x7f03f2224d70>], [<DMatch 0x7f03f2224d90>, <DMatch 0x7f03f2224db0>], [<DMatch 0x7f03f2224dd0>, <DMatch 0x7f03f2224df0>], [<DMatch 0x7f03f2224e10>, <DMatch 0x7f03f2224e30>], [<DMatch 0x7f03f2224e50>, <DMatch 0x7f03f2224e70>], [<DMatch 0x7f03f2224e90>, <DMatch 0x7f03f2224eb0>], [<DMatch 0x7f03f2224ed0>, <DMatch 0x7f03f2224ef0>], [<DMatch 0x7f03f2224f10>, <DMatch 0x7f03f2224f30>], [<DMatch 0x7f03f2224f50>, <DMatch 0x7f03f2224f7 ...

# %%
good=[]
not_good = []
for m,n in matches:
    if(m.distance < 0.75 * n.distance):
        good.append([m])
    else:
        not_good.append(m)

draw_param = dict(matchColor = (0,255,0),flags=2)
img3 =cv2.drawMatchesKnn(imageRight,kpr,imageLeft,kpl,good,None,**draw_param)
#img4 =cv2.drawMatches(imageLeft,kpl,imageRight,kpr,matches,None,**draw_param)

# %%
def trim(frame):
    #crop top
    if not np.sum(frame[0]):
        return trim(frame[1:])
    #crop bottom
    elif not np.sum(frame[-1]):
        return trim(frame[:-2])
    #crop left
    elif not np.sum(frame[:,0]):
        return trim(frame[:,1:])
    #crop right
    elif not np.sum(frame[:,-1]):
        return trim(frame[:,:-2])
    return frame

# %% [markdown]
# Reconstruct the whole image by image stitching.
# Here we warp based on the perseption where the common regions are merged to form a big picture and then trim out the excess region

# %%
def warpTwoImages(img1, img2, H):
    '''warp img2 to img1 with homograph H'''
    h1,w1 = img1.shape[:2]
    h2,w2 = img2.shape[:2]
    pts1 = np.float32([[0,0],[0,h1],[w1,h1],[w1,0]]).reshape(-1,1,2)
    pts2 = np.float32([[0,0],[0,h2],[w2,h2],[w2,0]]).reshape(-1,1,2)
    pts2_ = cv2.perspectiveTransform(pts2, H)
    pts = np.concatenate((pts1, pts2_), axis=0)
    [xmin, ymin] = np.int32(pts.min(axis=0).ravel() - 0.5)
    [xmax, ymax] = np.int32(pts.max(axis=0).ravel() + 0.5)
    t = [-xmin,-ymin]
    Ht = np.array([[1,0,t[0]],[0,1,t[1]],[0,0,1]]) # translate
    result = cv2.warpPerspective(img2, Ht.dot(H), (xmax-xmin, ymax-ymin))
    result[t[1]:h1+t[1],t[0]:w1+t[0]] = img1
    return result

# %%
# Homography graph Best matching points
MIN_MATCH_COUNT = 10
if len(good) > MIN_MATCH_COUNT:
    print("**** Strated the Panaroma Stitching*******")
    src_pts = np.float32([kpr[m[-1].queryIdx].pt for m in good]).reshape(-1,1,2)
    des_pts = np.float32([kpl[m[-1].trainIdx].pt for m in good]).reshape(-1,1,2)
    M,mask  = cv2.findHomography(src_pts,des_pts,cv2.RANSAC,5.0)
    result = warpTwoImages(imageLeft,imageRight, M)
    cv2_imshow( result)
else:
    print("Not Enough Matches : Less that Threshold")

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# **** Strated the Panaroma Stitching*******
# <PIL.Image.Image image mode=RGB size=1002x500 at 0x7F03F226BF98>

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(imageRight)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F03F19AE1D0>

# %%
cv2_imshow(imageLeft)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F03F19AE080>
